# %% [markdown]
# # Getting the Data

# %%
import pandas as pd

# %%
#users = pd.read_csv('users.csv', sep='\t')
#items = pd.read_csv('items.csv', sep='\t')
interactions = pd.read_csv('interactions.csv', sep='\t') # loads endlessly


# targetItems = pd.read_csv('targetItems.csv', sep='\t')
# targetUsers = pd.read_csv('targetUsers.csv', sep='\t')

# %% [markdown]
# # 1. User-Data

# %%
users.columns
# Out:
# Index(['recsyschallenge_v2017_users_final_anonym_export_unique.id',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.jobroles',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.career_level',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.discipline_id',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.industry_id',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.country',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.region',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.experience_n_entries_class',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.experience_years_experience',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.experience_years_in_current',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.edu_degree',
#        'recsyschallenge_v2017_users_final_anonym_export_unique.edu_fieldofstudies',
# ...

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.rename(inplace = True, index=str, columns={"A": "a", "B": "c"})
df
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
users.head(5)
# Out:
#    recsyschallenge_v2017_users_final_anonym_export_unique.id  \
# 0                                                 30
# 1                                                 50
# 2                                                 70
# 3                                                 90
# 4                                                100
#
#   recsyschallenge_v2017_users_final_anonym_export_unique.jobroles  \
# 0                                            2551922
# 1                    4375874,3415336,2152789,1431010
# 2                                     851763,2070276
# 3             2139882,2177068,1520218,3113130,399936
# 4                      233434,3142896,3836967,987884
#
#    recsyschallenge_v2017_users_final_anonym_export_unique.career_level  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  0
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497020 entries, 0 to 1497019
# Data columns (total 14 columns):
# recsyschallenge_v2017_users_final_anonym_export_unique.id                             1497020 non-null int64
# recsyschallenge_v2017_users_final_anonym_export_unique.jobroles                       1497020 non-null object
# recsyschallenge_v2017_users_final_anonym_export_unique.career_level                   1497020 non-null int64
# recsyschallenge_v2017_users_final_anonym_export_unique.discipline_id                  1497020 non-null int64
# recsyschallenge_v2017_users_final_anonym_export_unique.industry_id                    1497020 non-null int64
# recsyschallenge_v2017_users_final_anonym_export_unique.country                        1497020 non-null object
# recsyschallenge_v2017_users_final_anonym_export_unique.region                         1497020 non-null int64
# ...

# %%
feature_names = ['recsyschallenge_v2017_users_final_anonym_export_unique.id',
     'recsyschallenge_v2017_users_final_anonym_export_unique.jobroles', 
     'recsyschallenge_v2017_users_final_anonym_export_unique.career_level', 
     'recsyschallenge_v2017_users_final_anonym_export_unique.discipline_id',
     'recsyschallenge_v2017_users_final_anonym_export_unique.industry_id',
     'recsyschallenge_v2017_users_final_anonym_export_unique.country',
     'recsyschallenge_v2017_users_final_anonym_export_unique.region',
     'recsyschallenge_v2017_users_final_anonym_export_unique.experience_n_entries_class',
     'recsyschallenge_v2017_users_final_anonym_export_unique.experience_years_experience',
     'recsyschallenge_v2017_users_final_anonym_export_unique.experience_years_in_current',
     'recsyschallenge_v2017_users_final_anonym_export_unique.edu_degree',
     'recsyschallenge_v2017_users_final_anonym_export_unique.edu_fieldofstudies',
     'recsyschallenge_v2017_users_final_anonym_export_unique.wtcj',
     'recsyschallenge_v2017_users_final_anonym_export_unique.premium']

# %%
for name in feature_names:
    new_name = name[55:]
    users[new_name] = users[name]

# %%
for name in feature_names:
    users = users.drop(name, axis=1)

# %%
users.head(10)
# Out:
#     id                                jobroles  career_level  discipline_id  \
# 0   30                                 2551922             3              0
# 1   50         4375874,3415336,2152789,1431010             3              4
# 2   70                          851763,2070276             3             17
# 3   90  2139882,2177068,1520218,3113130,399936             0              0
# 4  100           233434,3142896,3836967,987884             3              0
# 5  120                         3152052,4009156             3              0
# 6  130                                       0             0              0
# 7  150                    519876,302644,821798             3              0
# 8  170                                 4099592             0              0
# 9  180                                 2967883             6             23
#
#    industry_id   country  region  experience_n_entries_class  \
# 0            0        de       0                           1
# ...

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497020 entries, 0 to 1497019
# Data columns (total 14 columns):
# id                             1497020 non-null int64
# jobroles                       1497020 non-null object
# career_level                   1497020 non-null int64
# discipline_id                  1497020 non-null int64
# industry_id                    1497020 non-null int64
# country                        1497020 non-null object
# region                         1497020 non-null int64
# experience_n_entries_class     1497020 non-null int64
# experience_years_experience    1497020 non-null int64
# experience_years_in_current    1497020 non-null int64
# edu_degree                     1497020 non-null int64
# edu_fieldofstudies             703689 non-null object
# wtcj                           1497020 non-null int64
# premium                        1497020 non-null int64
# dtypes: int64(11), object(3)
# memory usage: 159.9+ MB

# %% [markdown]
# # 2. Items-Data

# %%
items.head(5)
# Out:
#    recsyschallenge_v2017_items_final_training_export.id  \
# 0                                                 30
# 1                                                 70
# 2                                                 80
# 3                                                 90
# 4                                                100
#
#   recsyschallenge_v2017_items_final_training_export.title  \
# 0                                                NaN
# 1               2994300,665762,901938,127655,3680343
# 2                             3275701,157228,4179835
# 3                                            2343474
# 4                                            2003688
#
#    recsyschallenge_v2017_items_final_training_export.career_level  \
# 0                                                  3
# 1                                                  3
# 2                                                  1
# 3                                                  3
# ...

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1306054 entries, 0 to 1306053
# Data columns (total 13 columns):
# recsyschallenge_v2017_items_final_training_export.id               1306054 non-null int64
# recsyschallenge_v2017_items_final_training_export.title            1204338 non-null object
# recsyschallenge_v2017_items_final_training_export.career_level     1306054 non-null int64
# recsyschallenge_v2017_items_final_training_export.discipline_id    1306054 non-null int64
# recsyschallenge_v2017_items_final_training_export.industry_id      1306054 non-null int64
# recsyschallenge_v2017_items_final_training_export.country          1306054 non-null object
# recsyschallenge_v2017_items_final_training_export.is_payed         1306054 non-null int64
# recsyschallenge_v2017_items_final_training_export.region           1306054 non-null int64
# recsyschallenge_v2017_items_final_training_export.latitude         1306054 non-null object
# ...

# %%
feature_names = ['recsyschallenge_v2017_items_final_training_export.id',
                 'recsyschallenge_v2017_items_final_training_export.title',
                 'recsyschallenge_v2017_items_final_training_export.career_level',
                 'recsyschallenge_v2017_items_final_training_export.discipline_id',
                 'recsyschallenge_v2017_items_final_training_export.industry_id',
                 'recsyschallenge_v2017_items_final_training_export.country',
                 'recsyschallenge_v2017_items_final_training_export.is_payed',
                 'recsyschallenge_v2017_items_final_training_export.region',
                 'recsyschallenge_v2017_items_final_training_export.latitude',
                 'recsyschallenge_v2017_items_final_training_export.longitude',
                 'recsyschallenge_v2017_items_final_training_export.employment',
                 'recsyschallenge_v2017_items_final_training_export.tags',
                 'recsyschallenge_v2017_items_final_training_export.created_at',
]

# %%
for name in feature_names:
    new_name = name[50:]
    items[new_name] = items[name]

# %%
for name in feature_names:
    items = items.drop(name, axis=1)

# %%
items.head(5)
# Out:
#     id                                 title  career_level  discipline_id  \
# 0   30                                   NaN             3             15
# 1   70  2994300,665762,901938,127655,3680343             3              5
# 2   80                3275701,157228,4179835             1             10
# 3   90                               2343474             3              8
# 4  100                               2003688             4              8
#
#    industry_id country  is_payed  region latitude longitude  employment  \
# 0            9      de         0       7     50.8       8.9           1
# 1           18      de         0       1     48.7       9.0           1
# 2            1      de         0       1     48.8       8.1           1
# 3            9      de         0       3     52.5      13.4           1
# 4            3      at         0       0     48.1      15.1           1
#
#                                                 tags  created_at
# ...

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1306054 entries, 0 to 1306053
# Data columns (total 13 columns):
# id               1306054 non-null int64
# title            1204338 non-null object
# career_level     1306054 non-null int64
# discipline_id    1306054 non-null int64
# industry_id      1306054 non-null int64
# country          1306054 non-null object
# is_payed         1306054 non-null int64
# region           1306054 non-null int64
# latitude         1306054 non-null object
# longitude        1306054 non-null object
# employment       1306054 non-null int64
# tags             1275300 non-null object
# created_at       1306054 non-null object
# dtypes: int64(7), object(6)
# memory usage: 129.5+ MB
